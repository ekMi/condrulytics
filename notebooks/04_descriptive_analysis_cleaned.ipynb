# %%
import pandas as pd
df = pd.read_parquet("../data/cleaned/results.parquet")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 114761 entries, 0 to 114776
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Position            114761 non-null  int64
#  1   Nom                 114761 non-null  str
#  2   Club                113457 non-null  str
#  3   Sexe                114761 non-null  str
#  4   Categorie           114761 non-null  str
#  5   Position Catégorie  114761 non-null  int64
#  6   Temps               114761 non-null  str
#  7   NomCourse           114761 non-null  str
#  8   Date                114761 non-null  datetime64[us]
#  9   Distance            114761 non-null  float64
#  10  source_file         114761 non-null  str
#  11  racekey             114761 non-null  str
#  12  categorie_cleaned   114761 non-null  str
#  13  temps_clean         114761 non-null  timedelta64[us]
#  14  temps_sec           114761 non-null  int32
# ...

# %%
print(len(df['Nom'].unique()))
print(len(df['Nom_clean'].unique()))
# Out:
# 25178
# 24264

# %%
runner_counts = df["Nom_clean"].value_counts()
runner_counts.describe()
# Out:
# count    24264.000000
# mean         4.729682
# std         13.095986
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# max        246.000000
# Name: count, dtype: float64

# %%
runner_counts.value_counts().sort_index()
# Out:
# count
# 1      14177
# 2       3373
# 3       1565
# 4        946
# 5        632
#        ...
# 211        1
# 228        1
# 231        1
# 242        1
# 246        2
# Name: count, Length: 160, dtype: int64

# %%
# Coureurs ayant plusieurs valeurs de sexe différentes
incoherent_sexe = (
    df.groupby("Nom_clean")["Sexe"]
    .nunique()
    .reset_index()
)

# filtrer ceux qui ont plus d'un sexe
incoherent_sexe = incoherent_sexe[incoherent_sexe["Sexe"] > 1]

# récupérer la liste des noms
liste_coureurs_incoherents = incoherent_sexe["Nom_clean"].tolist()

# %%
df[df["Nom_clean"].isin(liste_coureurs_incoherents)] \
    .sort_values(["Nom_clean", "Date"])
# Out:
#         Position           Nom Club Sexe Categorie  Position Catégorie  \
# 100079       233  Andre Claude         F       V2F                   6
# 93505        293  Andre Claude         F       V2F                   6
# 49808        229  Andre Claude         F       V2F                   7
# 55556        242   Andre Claud         F       V2F                   8
# 103093       233  Andre Claude         F       V2F                   5
# ...          ...           ...  ...  ...       ...                 ...
# 85419        236           Xxx         X       XXX                   0
# 67254        116           Xxx         X       XXX                   0
# 106077       164           Xxx         X       XXX                   0
# 84234        101           Xxx         X       XXX                   0
# 67989         66           Xxx         X       XXX                   0
#
#            Temps                                NomCourse       Date  \
# ...

# %%
df[df['Nom_clean'] == "CAO CHRISTOPHE"]
# Out:
#         Position              Nom           Club Sexe Categorie  \
# 4082         212   Cao Christophe                   X       XXX
# 6920         119   Cao Christophe    Chicken Run    H       V1H
# 8341         152   Cao Christophe                   H       V1H
# 9670         165   Cao Christophe    Chicken Run    H       V1H
# 12777        165   Cao Christophe                   H        V1
# 13422        156   Cao Christophe    Chicken Run    H       V1H
# 14042        218   Cao Christophe    Chicken Run    H       V1H
# 15386        163   Cao Christophe    Chicken Run    H       VE1
# 17247        155   Cao Christophe    Chicken Run    H       V1H
# 18452        153   Cao Christophe                   H        V1
# 23124        147   Cao Christophe    Chicken Run    H       V1H
# 25504        216   Cao Christophe    Chicken Run    H       VE1
# 31841        307   Cao Christophe                   H       V1H
# 34689         95   Cao Christophe    Chicken Run    H       V1H
# ...
